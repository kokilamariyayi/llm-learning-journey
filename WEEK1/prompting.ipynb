# %% [markdown]
# PROMPTING

# %%
import os
from dotenv import load_dotenv
from groq import Groq

load_dotenv()
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

sentence = "John Doe, age 28, joined Infosys on March 15 2023 as a Data Analyst."

# %%
# PROMPT 1 - Zero shot
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": f"Extract information from this: {sentence}"}
    ]
)
print("ZERO SHOT:\n", response.choices[0].message.content)
# Out:
# ZERO SHOT:
#  Here's the information that can be extracted:
#
# 1. **Name**: John Doe
# 2. **Age**: 28
# 3. **Company**: Infosys
# 4. **Job Title**: Data Analyst
# 5. **Joining Date**: March 15, 2023

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": """Extract information as JSON. Only output the JSON, nothing else.

Example:
Input: Jane Smith, age 32, joined TCS on June 1 2021 as a Software Engineer.
Output: {"name": "Jane Smith", "age": 32, "company": "TCS", "join_date": "June 1 2021", "role": "Software Engineer"}

Input: John Doe, age 28, joined Infosys on March 15 2023 as a Data Analyst.
Output:"""
        }
    ]
)
print("FEW SHOT OUTPUT:")
print(response.choices[0].message.content)
# Out:
# FEW SHOT OUTPUT:
# {"name": "John Doe", "age": 28, "company": "Infosys", "join_date": "March 15 2023", "role": "Data Analyst"}

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "system",
            "content": "You are an information extractor. You only output valid JSON. No explanation. No extra text. Just JSON."
        },
        {
            "role": "user",
            "content": "John Doe, age 28, joined Infosys on March 15 2023 as a Data Analyst."
        }
    ]
)
print("SYSTEM PROMPT OUTPUT:")
print(response.choices[0].message.content)
# Out:
# SYSTEM PROMPT OUTPUT:
# ```
# {
#   "name": "John Doe",
#   "age": 28,
#   "company": "Infosys",
#   "join_date": "2023-03-15",
#   "role": "Data Analyst"
# }
# ```
